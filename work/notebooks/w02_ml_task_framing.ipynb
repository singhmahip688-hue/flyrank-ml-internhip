# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/singhmahip688-hue/flyrank-ml-internhip/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# ## 1.  Ranking/Scoring Task Type
#
# This project is a ranking/scoring task implemented using binary classification. The model predicts the probability that a page is declining, and pages are then ranked by this probability so reviewers can prioritize which pages to inspect first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# ## 2. Target (Proxy)
#
# The proxy target is whether a page is currently declining:
#
# is_declining_label = (trend_direction == "down")
#
# This is a proxy rather than an ideal target because it is based on the current observation window instead of a future outcome. A stronger approach would use historical features (for example, the previous 90 days) to predict whether a page will decline during the next 30 days.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
df["is_declining_label"] = df["trend_direction"] == "down"

df[[
    "content_id",
    "trend_direction",
    "is_declining_label"
]].head(10)

print(df["is_declining_label"].value_counts(normalize=True))
# Out:
# is_declining_label
# True     0.542067
# False    0.457933
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# ## 3. Success Metric
#
# The primary evaluation metric is Precision@50.
#
# The model ranks pages by their predicted probability of decline, and only the top 50 pages are reviewed. Precision@50 measures how many of those top-ranked pages are actually declining, which matches the real workflow of content reviewers.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# !git clone https://github.com/singhmahip688-hue/flyrank-ml-internhip.git
# Out:
# fatal: destination path 'flyrank-ml-internhip' already exists and is not an empty directory.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("flyrank-ml-internhip/data/raw/content_refresh_anonymized.csv")

df[[
    "content_id",
    "client_id",
    "impressions_90d",
    "trend_direction",
    "days_since_last_update"
]].head()
# Out:
#              content_id          client_id  impressions_90d trend_direction  \
# 0  content_304f48230142  client_f369cb89fc             3803            down
# 1  content_a1fb4e703a9e  client_4e07408562            15320            down
# 2  content_9aa793d4d895  client_7f2253d7e2            12581            down
# 3  content_331d6c4de07b  client_19581e27de            11751          stable
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140            down
#
#    days_since_last_update
# 0                      20
# 1                      25
# 2                      20
# 3                      22
# 4                      14

# %% [markdown]
# ## 4. Unit of Analysis
#
# Each row in the dataset represents one content page identified by `content_id`. The model makes one prediction for each page, allowing pages to be ranked based on their likelihood of decline.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why Machine Learning?
#
# A simple rule-based approach uses fixed thresholds to identify declining pages, but it cannot capture complex relationships between multiple signals.
#
# According to the starter project's results, the baseline rule achieves a Precision@50 of about 0.24, while the Random Forest model achieves approximately 0.74. This shows that combining multiple features such as visibility, freshness, search position, and engagement enables the model to identify declining pages much more effectively than a fixed rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
